# %%
import pandas as pd

# Load the unified annotation CSV
csv_path = "../features-extraction/features-relative.csv"
df = pd.read_csv(csv_path)

# Count occurrences of each label
label_counts = df["Label"].value_counts()

print(label_counts)
